# %%
def dfs(graph, s):
    stack, path = [s], []
    while stack:
        vertex = stack.pop()
        path.append(vertex)
        for neighbor in graph[vertex]:
            stack.append(neighbor)

    return path

def DLS(self, s, t, d):
    if s == t: return True
    if d<=0: return False
    for i in self.graphlist[s]:
      if (self.DLS(i, t, d-1)):
        return True
    return False

def DLS(s, t, d):
    if s == t: return True
    if d<=0: return False
    for i in adjacency_matrix[s]:
        print(i)
        if (DLS(i, t, d-1)):
            return True
    return False

adjacency_matrix = {
      'Arad' : ['Zerind', 'Timisoara', 'Sibiu'], 
      'Zerind' : ['Oradea'],
      'Timisoara' : ['Lugoj'],
      'Sibiu' : ['Rimnicu Vilcea', 'Fagaras'],
      'Oradea' : [],
#       'Oradea' : ['Sibiu'],
      'Lugoj' : [],
      'Rimnicu Vilcea' : [],
      'Fagaras' : [],
#     'Fagaras' : ['Bucharest'],
#       'Bucharest': []
  }
s=str(input("Enter Value of source point : "))
t=str(input("Enter Value of target point : "))
d=int(input("Enter Value of depth value : "))
print("\n")
#     Cetak DFS
print("Metode DFS")
print("Routenya adalah : ")
route = dfs(adjacency_matrix, s)
for a in route:
    print(a)
    if a == t:
        break
#     Cetak DLS
print("\n")
print("Metode DLS")
print("with depth : "+ str(d))
print(DLS(s, t, d))

# %%
def dfs(graph, s):
    stack, path = [s], []
    while stack:
        vertex = stack.pop()
        path.append(vertex)
        for neighbor in graph[vertex]:
            stack.append(neighbor)
    return path

# def DLS(s, t, d, graph):
#     stack, path = [s], []
#     while stack:
        
#         print(path)
#         vertex = stack.pop()
#         path.append(vertex)
#         for neighbor in graph[vertex]:
#             stack.append(neighbor)
#     return path


def DLS(visited, graph, node):
    if node not in visited:
        print (node)
        visited.add(node)
        for neighbor in graph[node]:
            dfs(visited, graph, neighbor)
    

adjacency_matrix = {
      'Arad' : ['Zerind', 'Timisoara', 'Sibiu'], 
      'Zerind' : ['Oradea'],
      'Timisoara' : ['Lugoj'],
      'Sibiu' : ['Rimnicu Vilcea', 'Fagaras'],
      'Oradea' : ['Sibiu'],
      'Lugoj' : [],
      'Rimnicu Vilcea' : [],
      'Fagaras' : ['Bucharest'],
      'Bucharest': []
  }
s=str(input("Enter Value of source point : "))
t=str(input("Enter Value of target point : "))
d=int(input("Enter Value of depth value : "))
print("\n")
#     Cetak DFS
print("Metode DFS")
print("Routenya adalah : ")
route = dfs(adjacency_matrix, s)
for a in route:
    print(a)
    if a == t:
        break
#     Cetak DLS
print("\n")
print("Metode DLS")
print("with depth : "+ str(d))
DLS(s, adjancency_matrix, )
# Out:
# Enter Value of source point : Arad
# Enter Value of target point : Oradea
# Enter Value of depth value : 2
#
#
# Metode DFS
# Routenya adalah :
# Arad
# Sibiu
# Fagaras
# Bucharest
# Rimnicu Vilcea
# Timisoara
# Lugoj
# Zerind
# Oradea
#
#
# Metode DLS
# with depth : 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d09290d7d727> in <module>
#      55 print("Metode DLS")
#      56 print("with depth : "+ str(d))
# ---> 57 DLS(s, adjancency_matrix, )
#
# NameError: name 'adjancency_matrix' is not defined
